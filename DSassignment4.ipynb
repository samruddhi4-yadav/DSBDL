# %%
import pandas as pd

# %%
df=pd.read_csv("dataset_facebook.csv",sep=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
# a. Create data subsets

# %%
subset1 = df[['Type', 'Category', 'like', 'share']]
subset1.head()
# Out:
#      Type  Category    like  share
# 0   Photo         2    79.0   17.0
# 1  Status         2   130.0   29.0
# 2   Photo         3    66.0   14.0
# 3   Photo         2  1572.0  147.0
# 4   Photo         2   325.0   49.0

# %%
df[['Type','like']].head()
# Out:
#      Type    like
# 0   Photo    79.0
# 1  Status   130.0
# 2   Photo    66.0
# 3   Photo  1572.0
# 4   Photo   325.0

# %%
subset2 = df[df['like'] > 100]
subset2.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 5   0.0                      10472                            20849
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.loc[[1,3,7]]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 3            139441   Photo         2          12             2         10
# 7            139441   Photo         3          12             7          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 3   1.0                      50128                            87991
# 7   1.0                      13720                            24137
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 1                    1457                     1361
# 3                    2211                      790
# 7                     537                      232
#
#    Lifetime Post Consumptions  \
# 1                        1674
# 3                        1119
# 7                         305
#
# ...

# %%
subset4 = df.iloc[1:10, 1:6]
subset4
# Out:
#      Type  Category  Post Month  Post Weekday  Post Hour
# 1  Status         2          12             3         10
# 2   Photo         3          12             3          3
# 3   Photo         2          12             2         10
# 4   Photo         2          12             2          3
# 5  Status         2          12             1          9
# 6   Photo         3          12             1          3
# 7   Photo         3          12             7          9
# 8  Status         2          12             7          3
# 9   Photo         3          12             6         10

# %%
df.loc[5:8]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 5   0.0                      10472                            20849
# 6   1.0                      11692                            19479
# 7   1.0                      13720                            24137
# 8   0.0                      11844                            22538
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 5                    1191                     1073
# 6                     481                      265
# 7                     537                      232
# ...

# %%
df.loc[1:7,['like','share']]
# Out:
#      like  share
# 1   130.0   29.0
# 2    66.0   14.0
# 3  1572.0  147.0
# 4   325.0   49.0
# 5   152.0   33.0
# 6   249.0   27.0
# 7   325.0   14.0

# %%
# b. Merge Data

# %%
df1 = pd.DataFrame({
    'employee': ['Bob','Jake','Lisa','Sue'],
    'group': ['Accounting','Engineering','Engineering','HR']
})

# %%
df2 = pd.DataFrame({
    'employee': ['Lisa','Bob','Jake','Sue'],
    'hire_date': [2004,2008,2012,2014]
})

# %%
merged = pd.merge(df1, df2)

# %%
merged
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df3 = pd.DataFrame({
    'group': ['Accounting','Engineering','HR'],
    'supervisor': ['Carly','Guido','Steve']
})

# %%
merged2 = pd.merge(merged, df3)

# %%
merged2
# Out:
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2008      Carly
# 1     Jake  Engineering       2012      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2014      Steve

# %%
subset1 = df.loc[1:5,['Category','like','share','Type']]
subset1
# Out:
#    Category    like  share    Type
# 1         2   130.0   29.0  Status
# 2         3    66.0   14.0   Photo
# 3         2  1572.0  147.0   Photo
# 4         2   325.0   49.0   Photo
# 5         2   152.0   33.0  Status

# %%
subset2 = df.loc[5:10,['Category','like','share','Type']]
subset2
# Out:
#     Category   like  share    Type
# 5          2  152.0   33.0  Status
# 6          3  249.0   27.0   Photo
# 7          3  325.0   14.0   Photo
# 8          2  161.0   31.0  Status
# 9          3  113.0   26.0   Photo
# 10         2  233.0   19.0  Status

# %%
print(subset1, '\n\n', subset2)
# Out:
#    Category    like  share    Type
# 1         2   130.0   29.0  Status
# 2         3    66.0   14.0   Photo
# 3         2  1572.0  147.0   Photo
# 4         2   325.0   49.0   Photo
# 5         2   152.0   33.0  Status
#
#      Category   like  share    Type
# 5          2  152.0   33.0  Status
# 6          3  249.0   27.0   Photo
# 7          3  325.0   14.0   Photo
# 8          2  161.0   31.0  Status
# 9          3  113.0   26.0   Photo
# 10         2  233.0   19.0  Status

# %%
merge_set = pd.concat([subset1, subset2], axis=0)
print(merge_set)
# Out:
#     Category    like  share    Type
# 1          2   130.0   29.0  Status
# 2          3    66.0   14.0   Photo
# 3          2  1572.0  147.0   Photo
# 4          2   325.0   49.0   Photo
# 5          2   152.0   33.0  Status
# 5          2   152.0   33.0  Status
# 6          3   249.0   27.0   Photo
# 7          3   325.0   14.0   Photo
# 8          2   161.0   31.0  Status
# 9          3   113.0   26.0   Photo
# 10         2   233.0   19.0  Status

# %%
merge_set.shape
# Out:
# (11, 4)

# %%
# Sorting Data

# %%
df.sort_values(by="like").head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 21    0.0                       1384                             2467
# 417   0.0                       1874                             2474
# 100   1.0                       1357                             2453
# 76    0.0                       1228                             2392
# 441   1.0                       1845                             2670
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.sort_values(by="like", ascending=False).head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 379   1.0                     105632                           147918
# 349   0.0                      81856                           124753
# 168   0.0                      41984                            68290
# 3     1.0                      50128                            87991
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.sort_values(by=["like","share"]).head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 417            104070  Photo         1           3             3         10
# 441             98195  Photo         1           3             5          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 21    0.0                       1384                             2467
# 76    0.0                       1228                             2392
# 100   1.0                       1357                             2453
# 417   0.0                       1874                             2474
# 441   1.0                       1845                             2670
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.sort_index().head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
# d. Transposing Data

# %%
df.head(10).T
# Out:
#                                                          0       1       2  \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                     0       0       0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.T.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...      490    491    492    493  \
# Page total likes  139441  139441  139441  ...    85979  85979  85979  85093
# Type               Photo  Status   Photo  ...    Photo  Photo   Link  Photo
# Category               3       2       3  ...        3      3      1      3
# Post Month            12      12      12  ...        1      1      1      1
# Post Weekday           7       7       6  ...        6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %%
# e. Shape and reshape Data

# %%
df.shape
# Out:
# (500, 19)

# %%
selective_df=pd.DataFrame(df.iloc[0:3],columns=['like','share','Category','Type'])
print(selective_df.head(5))
# Out:
#     like  share  Category    Type
# 0   79.0   17.0         2   Photo
# 1  130.0   29.0         2  Status
# 2   66.0   14.0         3   Photo

# %%
sub1 = df.loc[0:5,['Category', 'Post Month','Post Hour', 'Paid']]

sub1.melt(id_vars=['Category'])
# Out:
#     Category    variable  value
# 0          2  Post Month   12.0
# 1          2  Post Month   12.0
# 2          3  Post Month   12.0
# 3          2  Post Month   12.0
# 4          2  Post Month   12.0
# 5          2  Post Month   12.0
# 6          2   Post Hour    3.0
# 7          2   Post Hour   10.0
# 8          3   Post Hour    3.0
# 9          2   Post Hour   10.0
# 10         2   Post Hour    3.0
# 11         2   Post Hour    9.0
# 12         2        Paid    0.0
# 13         2        Paid    0.0
# 14         3        Paid    0.0
# 15         2        Paid    1.0
# 16         2        Paid    0.0
# 17         2        Paid    0.0

# %%
pivote_table=pd.pivot_table(selective_df,index=['Category'])
print(pivote_table)
# Out:
#            like  share
# Category
# 2         104.5   23.0
# 3          66.0   14.0

# %%
pivote_table.shape
# Out:
# (2, 2)

# %%
pivote_table.reset_index(inplace=True)
print(pivote_table)
# Out:
#    Category   like  share
# 0         2  104.5   23.0
# 1         3   66.0   14.0

# %%
pivote_table.melt(id_vars=['like','share'])
# Out:
#     like  share  variable  value
# 0  104.5   23.0  Category      2
# 1   66.0   14.0  Category      3
